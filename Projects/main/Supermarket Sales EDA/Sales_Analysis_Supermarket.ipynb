# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# ## constants and Static Variables

# %%
c_green = '#6DF10C'
c_yellow = '#F5DD0D'
c_cyan = '#0FFDEF'
c_blue = '#0141DE'
e = np.e

# %%
def df():
    df = pd.read_csv("csv\\supermarket_sales.csv")
    return df

# %%
df()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df().describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df().shape
# Out:
# (1000, 17)

# %%
df().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df().columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df().isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
product_line = df()['Product line'].unique()
product_line
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
city = df()['City'].unique()
city
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
city_group = df().groupby('City')

# %%
for city, city_df in city_group:
    print(city)
# Out:
# Mandalay
# Naypyitaw
# Yangon

# %%
city_group.get_group('Mandalay').describe()
# Out:
#        Unit price    Quantity      Tax 5%        Total        cogs  \
# count  332.000000  332.000000  332.000000   332.000000  332.000000
# mean    55.659277    5.481928   15.232024   319.872506  304.640482
# std     26.224559    2.896446   11.545122   242.447565  230.902443
# min     10.590000    1.000000    0.887500    18.637500   17.750000
# 25%     33.300000    3.000000    5.711250   119.936250  114.225000
# 50%     54.850000    5.000000   12.042000   252.882000  240.840000
# 75%     77.002500    8.000000   22.170750   465.585750  443.415000
# max     99.960000   10.000000   48.690000  1022.490000  973.800000
#
#        gross margin percentage  gross income      Rating
# count               332.000000    332.000000  332.000000
# mean                  4.761905     15.232024    6.818072
# std                   0.000000     11.545122    1.713719
# min                   4.761905      0.887500    4.000000
# 25%                   4.761905      5.711250    5.300000
# ...

# %%
city_group.get_group('Yangon').describe()
# Out:
#        Unit price    Quantity      Tax 5%        Total        cogs  \
# count  340.000000  340.000000  340.000000   340.000000  340.000000
# mean    54.780853    5.467647   14.874001   312.354031  297.480029
# std     26.132127    2.859876   11.030477   231.640025  220.609547
# min     10.080000    1.000000    0.604500    12.694500   12.090000
# 25%     32.250000    3.000000    6.547125   137.489625  130.942500
# 50%     53.235000    5.000000   11.468000   240.828000  229.360000
# 75%     75.095000    8.000000   21.873375   459.340875  437.467500
# max     99.830000   10.000000   49.490000  1039.290000  989.800000
#
#        gross margin percentage  gross income      Rating
# count               340.000000    340.000000  340.000000
# mean                  4.761905     14.874001    7.027059
# std                   0.000000     11.030477    1.731345
# min                   4.761905      0.604500    4.000000
# 25%                   4.761905      6.547125    5.600000
# ...

# %%
city_group.get_group('Naypyitaw').describe()
# Out:
#        Unit price    Quantity      Tax 5%        Total        cogs  \
# count  328.000000  328.000000  328.000000   328.000000  328.000000
# mean    56.609024    5.582317   16.052367   337.099715  321.047348
# std     27.179799    3.021724   12.531470   263.160870  250.629400
# min     10.160000    1.000000    0.508500    10.678500   10.170000
# 25%     33.767500    3.000000    5.784500   121.474500  115.690000
# 50%     56.810000    6.000000   12.924750   271.419750  258.495000
# 75%     81.552500    8.000000   23.607375   495.754875  472.147500
# max     99.960000   10.000000   49.650000  1042.650000  993.000000
#
#        gross margin percentage  gross income      Rating
# count               328.000000    328.000000  328.000000
# mean                  4.761905     16.052367    7.072866
# std                   0.000000     12.531470    1.704526
# min                   4.761905      0.508500    4.000000
# 25%                   4.761905      5.784500    5.600000
# ...

# %%
df()[df()['Total'] == df()['Total'].max() ]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 350        99.3        10   49.65  1042.65  2/15/2019  14:53  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 350  993.0                 4.761905         49.65     6.6

# %%
df()[df()['Total'] == df()['Total'].min() ]
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 822  784-21-9238      C  Naypyitaw        Member   Male  Sports and travel
#
#      Unit price  Quantity  Tax 5%    Total        Date   Time Payment   cogs  \
# 822       10.17         1  0.5085  10.6785  02-07-2019  14:15    Cash  10.17
#
#      gross margin percentage  gross income  Rating
# 822                 4.761905        0.5085     5.9

# %%
sns.barplot(x = 'City' , y = "Total" ,  data = df(), hue = 'Gender')
rcParams['figure.figsize'] = 8,5
plt.show()

# %%
df_str_dropped = df().drop(columns=['Invoice ID','Branch', 'City','Customer type','Gender' ,'Date','Time','Payment', 'Product line' , 'gross margin percentage'])
df_str_dropped
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  gross income  Rating
# 0         74.69         7  26.1415   548.9715  522.83       26.1415     9.1
# 1         15.28         5   3.8200    80.2200   76.40        3.8200     9.6
# 2         46.33         7  16.2155   340.5255  324.31       16.2155     7.4
# 3         58.22         8  23.2880   489.0480  465.76       23.2880     8.4
# 4         86.31         7  30.2085   634.3785  604.17       30.2085     5.3
# ..          ...       ...      ...        ...     ...           ...     ...
# 995       40.35         1   2.0175    42.3675   40.35        2.0175     6.2
# 996       97.38        10  48.6900  1022.4900  973.80       48.6900     4.4
# 997       31.84         1   1.5920    33.4320   31.84        1.5920     7.7
# 998       65.82         1   3.2910    69.1110   65.82        3.2910     4.1
# 999       88.34         7  30.9190   649.2990  618.38       30.9190     6.6
#
# [1000 rows x 7 columns]

# %%
df_corr = df_str_dropped.corr()
df_corr
# Out:
#               Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price      1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity        0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%          0.633962  0.705510  1.000000  1.000000  1.000000
# Total           0.633962  0.705510  1.000000  1.000000  1.000000
# cogs            0.633962  0.705510  1.000000  1.000000  1.000000
# gross income    0.633962  0.705510  1.000000  1.000000  1.000000
# Rating         -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#               gross income    Rating
# Unit price        0.633962 -0.008778
# Quantity          0.705510 -0.015815
# Tax 5%            1.000000 -0.036442
# Total             1.000000 -0.036442
# cogs              1.000000 -0.036442
# gross income      1.000000 -0.036442
# Rating           -0.036442  1.000000

# %%
sns.heatmap(df_corr, cmap = "gist_heat" , annot=True)
rcParams['figure.figsize'] = 10,6
plt.title('Correlation Between Numerical Data')
plt.show()

# %%
sns.histplot(df()['gross income'] ,  bins = [0,5,10,15,20,25,30,35,40,45,50] , kde = True , color = 'y')
rcParams['figure.figsize'] = 8,5
plt.title('Plot between Gross total income and its count')
plt.show()

# %%
sns.scatterplot(x = 'Total' , y ='gross income' , data = df() , color = 'g')
rcParams['figure.figsize'] = 8,5
plt.title('Plot Between Total Cart value vs Gross income')
plt.show()

# %%
sns.lineplot(x = 'Total' , y ='gross income' , data = df() , color = 'g')
rcParams['figure.figsize'] = 8,5
plt.title('Plot Between Total Cart value vs Gross income')
plt.show()

# %%
sns.histplot(df()['Rating'] ,bins = [4,5,6,7,8,9,10],kde = True , color = 'g')
rcParams['figure.figsize'] = 8,5
plt.title('Plot Between Rating and its count')
plt.show()

# %%
sns.histplot(df()['Total'] ,kde = True , color = 'y',bins=[0,50,100,200,300,400,500,600,700,800,900,1000])
rcParams['figure.figsize'] = 8,5
plt.title('Plot Between Total Cart values and its count')
plt.show()

# %%
gender_countplot = sns.countplot(x = 'Gender' , data = df())
rcParams['figure.figsize'] = 8,5
for bars in gender_countplot.containers:
    gender_countplot.bar_label(bars)

# %%
gender_sales = df().groupby(['Gender'] , as_index = False)['Total'].sum().sort_values(by = 'Total' , ascending = False)
gender_sales.to_csv('Files\\Genderwise Total Sales')
gender_sales
# Out:
#    Gender       Total
# 0  Female  167882.925
# 1    Male  155083.824

# %%
sns.barplot(x = 'Gender' , y = "Total" , data = gender_sales , color = 'g')
rcParams['figure.figsize'] = 8,5
plt.title('Plot of Gender vs Total ')
plt.show()

# %%
city_sales = df().groupby(['City'] , as_index=False )['Total'].sum().sort_values(by = 'Total' , ascending = False)
city_sales.to_csv('Files\\Citywise Sales Total')
city_sales
# Out:
#         City        Total
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705
# 0   Mandalay  106197.6720

# %%
sns.barplot(x = 'City' , y = 'Total' , data = city_sales , color = 'y')
rcParams['figure.figsize'] = 10,6
plt.show()

# %%
product_line = df().groupby(['Product line'] ,  as_index=False )['Total'].sum().sort_values(by = 'Total' , ascending=False)
product_line.to_csv('Files\\Product line Total') 
product_line
# Out:
#              Product line       Total
# 2      Food and beverages  56144.8440
# 5       Sports and travel  55122.8265
# 0  Electronic accessories  54337.5315
# 1     Fashion accessories  54305.8950
# 4      Home and lifestyle  53861.9130
# 3       Health and beauty  49193.7390

# %%
sns.barplot(x = 'Product line' , y = 'Total' , data = product_line , color = c_cyan)
rcParams['figure.figsize'] = 12,9
plt.title('Bargraph Between Product Categories and its Total Amount')
plt.xlabel('Product - Categories' , size= 15)
plt.ylabel('Total Amount' , size= 15)
plt.show()

# %%
product_line_gross_income = df().groupby(['Product line'] , as_index=False)['gross income'].sum().sort_values(by = 'gross income', ascending=False)
product_line_gross_income.to_csv('Files\\product line gross income')
product_line_gross_income
# Out:
#              Product line  gross income
# 2      Food and beverages     2673.5640
# 5       Sports and travel     2624.8965
# 0  Electronic accessories     2587.5015
# 1     Fashion accessories     2585.9950
# 4      Home and lifestyle     2564.8530
# 3       Health and beauty     2342.5590

# %%
sns.barplot(x = 'Product line' , y = 'gross income' , data = product_line_gross_income , color = c_blue)
rcParams['figure.figsize'] = 12,9
plt.title('Bargraph Between Product Categories and Total Gross Income')
plt.xlabel('Product - Categories' , size= 15)
plt.ylabel('Total Gross Income' , size= 15)
plt.show()

# %%
customer_type_gross_income = df().groupby(['Customer type'] ,  as_index=False)['gross income'].sum().sort_values(by = 'gross income', ascending=False)
customer_type_gross_income.to_csv('Files\\customer type gross income')
customer_type_gross_income
# Out:
#   Customer type  gross income
# 0        Member      7820.164
# 1        Normal      7559.205

# %%
sns.barplot(x = 'Customer type' , y ='gross income' , data = customer_type_gross_income , color = c_yellow)
rcParams['figure.figsize'] = 8,6
plt.title('Bargraph Between Customer type and total gross income')
plt.show()

# %%
gender_gross_income = df().groupby(['Gender'] , as_index=False)['gross income'].sum().sort_values(by = 'gross income' , ascending=False)
gender_gross_income
# Out:
#    Gender  gross income
# 0  Female      7994.425
# 1    Male      7384.944

# %%
sns.barplot(x = 'Gender' , y ='gross income' , data = gender_gross_income , color = c_green)
rcParams['figure.figsize'] = 8,6
plt.title('Bargraph Between Gender and total gross income')
plt.show()

# %%
payment = df()['Payment'].unique()
payment
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
payment_total = df().groupby(['Payment'] , as_index=False )['Total'].sum().sort_values(by = 'Total' , ascending=False)
payment_total.to_csv('Files\\Payment type_total')
payment_total
# Out:
#        Payment       Total
# 0         Cash  112206.570
# 2      Ewallet  109993.107
# 1  Credit card  100767.072

# %%
sns.barplot(x = 'Payment' , y = 'Total' , data = payment_total , color = c_blue)
plt.title('Bargraph Between Payment type and Total Sales')
plt.show()

# %%
sns.violinplot(x = 'City' , y = 'gross income' , data = df() , hue = "Gender" , palette='gist_heat')
rcParams['figure.figsize'] = 12,8
plt.title('Violin plot between city and gross income')
plt.show()

# %%
df()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...
