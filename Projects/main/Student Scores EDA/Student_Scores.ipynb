# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib import rcParams

# %%
def df():
    df = pd.read_csv('csv\\student_scores.csv')
    return df

# %%
c_green = '#6DF10C'
c_yellow = '#F5DD0D'
c_cyan = '#0FFDEF'
c_blue = '#0141DE'
e = np.e

# %%
df()
# Out:
#        Gender          ParentEduc     LunchType   TestPrep  \
# 0      female   bachelor's degree      standard       none
# 1      female        some college      standard        NaN
# 2      female     master's degree      standard       none
# 3        male  associate's degree  free/reduced       none
# 4        male        some college      standard       none
# ...       ...                 ...           ...        ...
# 30636  female         high school      standard       none
# 30637    male         high school      standard       none
# 30638  female         high school  free/reduced  completed
# 30639  female  associate's degree      standard  completed
# 30640    male        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 1                 married     sometimes          yes         0.0
# ...

# %%
df().isnull().sum()
# Out:
# Gender                    0
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df().describe()
# Out:
#          NrSiblings     MathScore  ReadingScore  WritingScore
# count  29069.000000  30641.000000  30641.000000  30641.000000
# mean       2.145894     66.558402     69.377533     68.418622
# std        1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000     10.000000      4.000000
# 25%        1.000000     56.000000     59.000000     58.000000
# 50%        2.000000     67.000000     70.000000     69.000000
# 75%        3.000000     78.000000     80.000000     79.000000
# max        7.000000    100.000000    100.000000    100.000000

# %%
df().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   ParentEduc           28796 non-null  object
#  2   LunchType            30641 non-null  object
#  3   TestPrep             28811 non-null  object
#  4   ParentMaritalStatus  29451 non-null  object
#  5   PracticeSport        30010 non-null  object
#  6   IsFirstChild         29737 non-null  object
#  7   NrSiblings           29069 non-null  float64
#  8   TransportMeans       27507 non-null  object
#  9   WklyStudyHours       29686 non-null  object
#  10  MathScore            30641 non-null  int64
#  11  ReadingScore         30641 non-null  int64
#  12  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 3.0+ MB

# %%
df().isnull().sum()
# Out:
# Gender                    0
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df = df().dropna()
df
# Out:
#        Gender          ParentEduc     LunchType   TestPrep  \
# 0      female   bachelor's degree      standard       none
# 2      female     master's degree      standard       none
# 4        male        some college      standard       none
# 5      female  associate's degree      standard       none
# 6      female        some college      standard  completed
# ...       ...                 ...           ...        ...
# 30636  female         high school      standard       none
# 30637    male         high school      standard       none
# 30638  female         high school  free/reduced  completed
# 30639  female  associate's degree      standard  completed
# 30640    male        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 2                  single     sometimes          yes         4.0
# ...

# %%
df.isnull().sum()
# Out:
# Gender                 0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %%
df.describe()
# Out:
#          NrSiblings     MathScore  ReadingScore  WritingScore
# count  20443.000000  20443.000000  20443.000000  20443.000000
# mean       2.145233     66.607592     69.501785     68.568067
# std        1.447239     15.349014     14.765192     15.452675
# min        0.000000      0.000000     10.000000      4.000000
# 25%        1.000000     56.000000     59.000000     58.000000
# 50%        2.000000     67.000000     70.000000     69.000000
# 75%        3.000000     78.000000     80.000000     79.000000
# max        7.000000    100.000000    100.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20443 entries, 0 to 30640
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               20443 non-null  object
#  1   ParentEduc           20443 non-null  object
#  2   LunchType            20443 non-null  object
#  3   TestPrep             20443 non-null  object
#  4   ParentMaritalStatus  20443 non-null  object
#  5   PracticeSport        20443 non-null  object
#  6   IsFirstChild         20443 non-null  object
#  7   NrSiblings           20443 non-null  float64
#  8   TransportMeans       20443 non-null  object
#  9   WklyStudyHours       20443 non-null  object
#  10  MathScore            20443 non-null  int64
#  11  ReadingScore         20443 non-null  int64
#  12  WritingScore         20443 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.2+ MB

# %%
df.columns
# Out:
# Index(['Gender', 'ParentEduc', 'LunchType', 'TestPrep', 'ParentMaritalStatus',
#        'PracticeSport', 'IsFirstChild', 'NrSiblings', 'TransportMeans',
#        'WklyStudyHours', 'MathScore', 'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
df
# Out:
#        Gender          ParentEduc     LunchType   TestPrep  \
# 0      female   bachelor's degree      standard       none
# 2      female     master's degree      standard       none
# 4        male        some college      standard       none
# 5      female  associate's degree      standard       none
# 6      female        some college      standard  completed
# ...       ...                 ...           ...        ...
# 30636  female         high school      standard       none
# 30637    male         high school      standard       none
# 30638  female         high school  free/reduced  completed
# 30639  female  associate's degree      standard  completed
# 30640    male        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 2                  single     sometimes          yes         4.0
# ...

# %%
df_str_dropped = df.drop(columns=['Gender','ParentEduc','LunchType','TestPrep','ParentMaritalStatus','PracticeSport','IsFirstChild','TransportMeans','WklyStudyHours'])
df_str_dropped
# Out:
#        NrSiblings  MathScore  ReadingScore  WritingScore
# 0             3.0         71            71            74
# 2             4.0         87            93            91
# 4             0.0         76            78            75
# 5             1.0         73            84            79
# 6             1.0         85            93            89
# ...           ...        ...           ...           ...
# 30636         2.0         59            61            65
# 30637         1.0         58            53            51
# 30638         1.0         61            70            67
# 30639         3.0         82            90            93
# 30640         1.0         64            60            58
#
# [20443 rows x 4 columns]

# %%
df_corr = df_str_dropped.corr()
df_corr
# Out:
#               NrSiblings  MathScore  ReadingScore  WritingScore
# NrSiblings      1.000000   0.002632      0.001727      0.002547
# MathScore       0.002632   1.000000      0.818181      0.807564
# ReadingScore    0.001727   0.818181      1.000000      0.952385
# WritingScore    0.002547   0.807564      0.952385      1.000000

# %%
sns.heatmap(df_corr , cmap = "gist_heat" , annot=True)
rcParams['figure.figsize'] = 10,7
plt.show()

# %%
parent_edu = df['ParentEduc'].unique()
parent_edu
# Out:
# array(["bachelor's degree", "master's degree", 'some college',
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
sns.barplot(x = 'ParentEduc' , y = 'MathScore' , data = df , palette= 'gist_heat', hue = 'Gender')
plt.show()

# %%
df['WklyStudyHours'].unique()
# Out:
# array(['< 5', '05-Oct', '> 10'], dtype=object)

# %%
df
# Out:
#        Gender          ParentEduc     LunchType   TestPrep  \
# 0      female   bachelor's degree      standard       none
# 2      female     master's degree      standard       none
# 4        male        some college      standard       none
# 5      female  associate's degree      standard       none
# 6      female        some college      standard  completed
# ...       ...                 ...           ...        ...
# 30636  female         high school      standard       none
# 30637    male         high school      standard       none
# 30638  female         high school  free/reduced  completed
# 30639  female  associate's degree      standard  completed
# 30640    male        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 2                  single     sometimes          yes         4.0
# ...
